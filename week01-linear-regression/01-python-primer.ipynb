# %% [markdown]
# # 🐍 Python Primer for ML Beginners
#
# Welcome to **Week 1 of zero-to-ml** 🌱
#
# This notebook teaches the **minimum Python** you need before building your first Machine Learning model.
#
# 👉 This is a **practice-focused notebook**, not a lecture.
# 👉 Try each exercise **before** scrolling to the solution.
# 👉 Modify code, break it, fix it — that’s how you learn.
# 👉 If something confuses you, write a note or comment inside the notebook.
#
# If you're learning through GitHub:
# - **Fork this repo**
# - Create: `students/<your-name>/week01/`
# - Add your completed notebook + reflections
# - Open a PR if you want feedback 🌟

# %% [markdown]
# # Basics: Variables

# %%
x = 5
name = "Mansi"
height = 5.3
is_student = True

print(x, name, height, is_student)

# %% [markdown]
# ## 🧩 Exercise 1: Variables
#
# Try these on your own:
#
# 1. Create variables for:
#    - your name
#    - your age
#    - your favourite color
#    - whether you like Python (True/False)
#
# 2. Print them together in one line.
#
# 3. Increase your age by 1 and print again.
#
# ✏️ Write your code below:

# %%
# ADD YOUR CODE HERE

# %% [markdown]
# # Basics: Lists

# %%
numbers = [10, 20, 30, 40]
print(numbers)
print("First:", numbers[0])
print("Length:", len(numbers))

# %% [markdown]
# ## 🧩 Exercise 2: Lists
#
# 1. Create a list of **5 fruits**.
# 2. Print the **first** and **last** fruit.
# 3. Add a new fruit to the list.
# 4. Remove one fruit.
# 5. Print the updated list and its length.
#
# Write your code below:

# %%
# ADD YOUR CODE HERE

# %% [markdown]
# # Basics: Loops

# %%
nums = [1, 2, 3, 4, 5]

for n in nums:
    print("Number:", n)

# %% [markdown]
# ## 🧩 Exercise 3: Loops
#
# 1. Create a list of numbers from **1 to 7**.
# 2. Print each number multiplied by **10**.
# 3. Print only **odd** numbers.
# 4. Print the **sum** of all numbers.

# %%
# ADD YOUR CODE HERE

# %% [markdown]
# # Basics: Function

# %%
def greet(name):
    return "Hello " + name

greet("world")

# %% [markdown]
# ## 🧩 Exercise 4: Functions
#
# Excercise 1:
# Write a function to take first-name and last-name and return the full name (Ex. Mansi Pandey)
#
# Excercise 2:
# Write a function to take a number and return square of the number.

# %%
# ADD YOUR CODE HERE

# %% [markdown]
# # Basics: NumPy

# %%
# Run this cell to install numpy

# %pip install numpy

# %%
import numpy as np

arr = np.array([1, 2, 3, 4, 5])
print(arr)
print(arr * 2)
print(arr + 10)

print("Mean:", arr.mean())
print("Max:", arr.max())
print("Min:", arr.min())

# %% [markdown]
# ## 🧩 Exercise 5: NumPy Practice
#
# Create a NumPy array: [10, 20, 30, 40]
#
#
# Then:
#
# 1. Multiply all numbers by **5**
# 2. Add **100** to each
# 3. Compute the:
#    - mean
#    - sum
#    - max

# %%
# ADD YOUR CODE HERE

# %% [markdown]
# # 📝 Quick Quiz
#
# Write your answers here (no need to scroll to any solution):
#
# 1. What is the difference between a **list** and a **NumPy array**?
# 2. What does a **function** do?
# 3. How do you access the **last item** in a list?
# 4. What does a loop do in Python?

# %% [markdown]
# # ADD YOUR ANSWER HERE

# %% [markdown]
# # ✨ Reflection
#
# Please answer in 1–2 sentences:
#
# 1. What part of Python felt easiest today?
# 2. What part felt confusing or new?
# 3. What would you like more examples of?

# %% [markdown]
# # ADD YOUR ANSWER HERE

# %% [markdown]
# # 🤝 Contribute Your Work
#
# If you're learning through GitHub:
#
# 1. Fork this repository
# 2. Create this folder:  students/<your-name>/week01/
# 3. Add **your completed notebook** + your reflections
# 4. Open a Pull Request with the title:
#
# **"Week 1 – Python Primer (My Version)"**
#
# You can also contribute by:
# - Adding new exercises
# - Adding examples in your own language
# - Adding simple diagrams explaining lists, loops, functions
# - Fixing mistakes or adding clarifications
#
# Your contributions help future beginners learn better 🌱

# %% [markdown]
# # ❓ Stuck? Ask a Question!
#
# If you're confused, open a GitHub Issue titled:
#
# **"Week 1 – Question: <your question>"**
#
# Include:
# - Screenshot of your code
# - What you expected
# - What happened instead
#
# No question is too small — this project is for **total beginners** ❤️

# %% [markdown]
# 🎉 CONGRATULATION ON COMPLETING YOUR FIRST EXCERCISE!

# %% [markdown]
# # 📚 Optional: Learn More About Python
#
# If you want to explore Python deeper, here are some beginner-friendly resources:
#
# **Videos**
# - Python Basics in 15 Minutes — https://youtu.be/kqtD5dpn9C8
# - NumPy Crash Course — https://youtu.be/GB9ByFAIAH4
#
# **Reading**
# - W3Schools Python — https://www.w3schools.com/python/
# - NumPy for Beginners — https://numpy.org/doc/stable/user/absolute_beginners.html
#
# Choose ANY one and spend 10–20 minutes.
# Don't overwhelm yourself — practice matters more than watching!
